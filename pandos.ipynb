# %%
import numpy as np
import pandas as pd

# %%
# i dataframe:
brent = pd.read_csv('BrentOilPrices.csv')

# %%
brent
# Out:
#               Date  Price
# 0        20-May-87  18.63
# 1        21-May-87  18.45
# 2        22-May-87  18.55
# 3        25-May-87  18.60
# 4        26-May-87  18.63
# ...            ...    ...
# 8355  Apr 15, 2020  19.80
# 8356  Apr 16, 2020  18.69
# 8357  Apr 17, 2020  19.75
# 8358  Apr 20, 2020  17.36
# 8359  Apr 21, 2020   9.12
#
# [8360 rows x 2 columns]

# %%
# .info()
brent.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8360 entries, 0 to 8359
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    8360 non-null   object
#  1   Price   8360 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 130.8+ KB

# %%
brent.head(15)
# Out:
#          Date  Price
# 0   20-May-87  18.63
# 1   21-May-87  18.45
# 2   22-May-87  18.55
# 3   25-May-87  18.60
# 4   26-May-87  18.63
# 5   27-May-87  18.60
# 6   28-May-87  18.60
# 7   29-May-87  18.58
# 8    1-Jun-87  18.65
# 9    2-Jun-87  18.68
# 10   3-Jun-87  18.75
# 11   4-Jun-87  18.78
# 12   5-Jun-87  18.65
# 13   8-Jun-87  18.75
# 14   9-Jun-87  18.78

# %%
brent.tail(15)
# Out:
#               Date  Price
# 8345  Mar 30, 2020  19.07
# 8346  Mar 31, 2020  19.19
# 8347  Apr 01, 2020  14.97
# 8348  Apr 02, 2020  20.24
# 8349  Apr 03, 2020  24.33
# 8350  Apr 06, 2020  22.58
# 8351  Apr 07, 2020  22.10
# 8352  Apr 08, 2020  25.22
# 8353  Apr 09, 2020  20.23
# 8354  Apr 14, 2020  21.74
# 8355  Apr 15, 2020  19.80
# 8356  Apr 16, 2020  18.69
# 8357  Apr 17, 2020  19.75
# 8358  Apr 20, 2020  17.36
# 8359  Apr 21, 2020   9.12

# %%
brent = pd.read_csv('BrentOilPrices.csv', parse_dates=['Date'])
# Out:
# C:\Users\csnoo\AppData\Local\Temp\ipykernel_31592\582957601.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   brent = pd.read_csv('BrentOilPrices.csv', parse_dates=['Date'])

# %%
brent.head()
# Out:
#         Date  Price
# 0 1987-05-20  18.63
# 1 1987-05-21  18.45
# 2 1987-05-22  18.55
# 3 1987-05-25  18.60
# 4 1987-05-26  18.63

# %%
#intergruotas pandas .plot metodas:
brent.plot(x='Date')
# Out:
# <Axes: xlabel='Date'>

# %%
ru = pd.read_csv('RU.csv', parse_dates=['Date'])
ru.head(3)
# Out:
#         Date    Open    High     Low   Close
# 0 1995-10-23  4.5065  4.5065  4.5065  4.5065
# 1 1995-10-24  4.5060  4.5060  4.5060  4.5060
# 2 1995-10-25  4.5060  4.5060  4.5060  4.5060

# %%
ru.plot(x='Date', y=['Open','Close'])
# Out:
# <Axes: xlabel='Date'>

# %%
dus14 = pd.read_csv('DUS2014.csv')
dus14.head(2)
# Out:
#    svoris  stazas  darbo_laiko_dalis evrk  im_dydzio_kodas im_dydis amzius  \
# 0   35.03       0               0.58   XL                0     1_49  20-29
# 1    2.39       0               0.54   XN                0     1_49  20-29
#
#    atostogu_dienos sutarties_rusis  virsvalandziu_bdu  ...  nuosavybe bdu_val  \
# 0                0               A                  0  ...          B     6.0
# 1                0               A                  0  ...          B     6.0
#
#    nuts  vv_darb_sk  virsvalandziu_sk premijos  bdu_spalio priemokos  \
# 0    LT           6                 0        0         6.0         0
# 1    LT          12                 0        0         6.0         0
#
#    objectid issilavinimas
# 0         1            G4
# 1         2            G2
#
# [2 rows x 32 columns]

# %%
bdu_spalio = dus14['bdu_spalio'].values
print(bdu_spalio.mean())
# Out:
# 2366.8490910304326

# %%
#keliu stulpeliu pasiemimas:
d14small = dus14[['lytis', 'amzius', 'bdu_spalio', 'issilavinimas', 'profesija']]
d14small.head()
# Out:
#   lytis amzius  bdu_spalio issilavinimas  profesija
# 0     M  20-29        6.00            G4        261
# 1     F  20-29        6.00            G2        334
# 2     F  40-49        6.00            G4        221
# 3     F  30-39        6.00            G4        332
# 4     M  40-49       11.33            G2        962

# %%
#doumenu atranka:
f14 = d14small[d14small['lytis'] == 'F']
f14.head(7)
# Out:
#    lytis amzius  bdu_spalio issilavinimas  profesija
# 1      F  20-29        6.00            G2        334
# 2      F  40-49        6.00            G4        221
# 3      F  30-39        6.00            G4        332
# 7      F  20-29       13.33            G2        531
# 10     F  40-49       10.00            G3        334
# 12     F  30-39        6.00            G4        241
# 13     F  20-29        9.00            G3        332

# %%
list = f14['lytis']
print(type(list)) # pandas.core.series.Series 
list = list.to_list()
print(type(list)) # list
# Out:
# <class 'pandas.core.series.Series'>
# <class 'list'>

# %%
f14vid = f14['bdu_spalio'].mean()
f14mediana = f14['bdu_spalio'].median()
print(f14vid, f14mediana)
# Out:
# 2097.379658410087 1751.0

# %%
m14 = d14small[d14small['lytis'] == 'M']
m14.head(7)
# Out:
#    lytis amzius  bdu_spalio issilavinimas  profesija
# 0      M  20-29        6.00            G4        261
# 4      M  40-49       11.33            G2        962
# 5      M  30-39        6.00            G2        122
# 6      M    60+        6.00            G4        221
# 8      M  20-29        6.67            G1        912
# 9      M  40-49        6.00            G2        332
# 11     M  20-29        9.67            G3        315

# %%
# koks buvo vyrų ir moterų vidutinis atlyginimas 2014 metais?
# rezulataą išspausdinkite vienas šalia kito:
# pvz 
# Vyrų x, moterų y atlyginimai
m14vid = m14['bdu_spalio'].mean()
f14vid = f14['bdu_spalio'].mean()
print('Vyru vidutinis atlyginimas:', m14vid, 'Moteru vidutinis atlyginimas:', f14vid, sep= '\n')
# Out:
# Vyru vidutinis atlyginimas:
# 2633.693743912158
# Moteru vidutinis atlyginimas:
# 2097.379658410087

# %%
# and ir or operatoriai:
# and = &
# or = |
# atrinkime tik vyrus, kuriu issilavinimas pazymetas G3
m14g3 = d14small[(d14small['lytis'] == 'M') & (d14small['issilavinimas'] == 'G3')]
m14g3.head()
# Out:
#    lytis amzius  bdu_spalio issilavinimas  profesija
# 11     M  20-29        9.67            G3        315
# 18     M    60+        6.00            G3        312
# 19     M  20-29        6.00            G3        333
# 21     M  20-29       28.67            G3        241
# 25     M  50-59        6.00            G3        261

# %%
# atrinkite tik vyrus
#pagal issilavinima
# G1, G2, G3, G4
#ir suraskite ju vidutinius atlyginimus
# spausdinkite taip:
# G1 x
# G2 y
# G3 z
# G4 e
m14g1 = d14small[(d14small['lytis'] == 'M') & (d14small['issilavinimas'] == 'G1')]
m14g2 = d14small[(d14small['lytis'] == 'M') & (d14small['issilavinimas'] == 'G2')]
m14g3 = d14small[(d14small['lytis'] == 'M') & (d14small['issilavinimas'] == 'G3')]
m14g4 = d14small[(d14small['lytis'] == 'M') & (d14small['issilavinimas'] == 'G4')]
m14g1vid = m14g1['bdu_spalio'].mean()
m14g2vid = m14g2['bdu_spalio'].mean()
m14g3vid = m14g3['bdu_spalio'].mean()
m14g4vid = m14g4['bdu_spalio'].mean()
print('G1 x:', m14g1vid)
print('G2 y:', m14g2vid)
print('G3 z:', m14g3vid)
print('G4 e:', m14g4vid)
# Out:
# G1 x: 1762.3009536541888
# G2 y: 2129.485699084385
# G3 z: 2900.4601477312694
# G4 e: 4158.559151846785
